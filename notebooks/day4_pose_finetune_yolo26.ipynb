# %% [markdown]
# # Tóm tắt notebook
#
# Notebook này dùng để kiểm định, đo baseline, fine-tune model pose và đối chiếu kết quả trên tập test. Mục tiêu không phải là đạt mAP tuyệt đối mà là nhìn rõ vòng lặp dữ liệu: nhãn của bạn -> baseline -> fine-tune -> đánh giá -> tìm sai sót kiểu nào.
#
# Thứ tự chạy rất quan trọng:
# 1. Clone hoặc mount repo.
# 2. Kiểm nhãn train để đảm bảo định dạng đúng.
# 3. Đo model gốc trên test.
# 4. Fine-tune bằng nhãn của bạn.
# 5. So sánh trước/sau bằng `pose_mAP50-95` và `box_mAP`.
# 6. Xem ảnh predict để gọi tên lỗi theo 4 loại: lệch nhẹ, đảo trái/phải, nhầm người, trượt hẳn.
# 7. Ghi các nhận xét vào báo cáo cuối cùng.
#
# > Lưu ý: Không dùng `gold/` để train. `data.yaml` phải giữ `val` trỏ tới tập test, không đổi sang train để nâng số.

# %% [markdown]
# # Ngày 4 - Từ 17 cái chấm của bạn đến một model pose
#
# Notebook này chạy **sau** khi nhãn của bạn đã qua cổng gold (`tools/evaluate_pose_annotations.py`).
# Trình tự: kiểm nhãn -> đo model gốc -> fine-tune trên nhãn của bạn -> đo lại -> nhìn tận mắt.
#
# ## Hợp đồng chạy
#
# - Chọn **một** cách đưa bài của bạn lên Colab: clone fork GitHub ở cell 0 (khuyến nghị), hoặc upload/mount thư mục `Day4-Lab/`.
# - Nếu clone fork: push `dataset/labels/train/`, `annotations/`, `reports/`, `outputs/` và `GUIDELINE_MINI.md` lên **fork của bạn** trước.
# - **Không** upload protected reference. Nếu bạn có `gold/`, nó cũng không được dùng để train.
# - Chạy từ trên xuống. Không đổi `val` trong `data.yaml` sang tập train để làm đẹp số.
# - 20 ảnh là quá ít để ra một model dùng được. Cái bạn đo hôm nay là **vòng lặp dữ liệu**,
#   không phải chất lượng sản phẩm. Con số quan trọng là *chênh lệch* giữa trước và sau fine-tune.

# %% [markdown]
# ## 0. Đưa fork của bạn vào Colab (khuyến nghị)
#
# Dán URL HTTPS của **fork có nhãn của bạn** vào `REPO_URL`, rồi chạy cell dưới. Cell này không xoá hoặc ghi đè thư mục nào.
#
# Nếu bạn đã upload/mount `Day4-Lab/`, để `REPO_URL` trống và chạy cell dưới để bỏ qua bước clone.

# %%
import subprocess
from pathlib import Path

# Ví dụ: https://github.com/cuongherok4/K4-Day4-HoangManhCuong-2A202602078-KeypointPose-Student.git
# Để trống nếu bạn upload/mount thư mục Day4-Lab thay vì clone fork.
REPO_URL = "https://github.com/cuongherok4/K4-Day4-HoangManhCuong-2A202602078-KeypointPose-Student.git"
WORKDIR = Path('/content') if Path('/content').is_dir() else Path.cwd()
LAB_ROOT = WORKDIR / 'Day4-Lab'

if REPO_URL.strip():
    if '<' in REPO_URL or '>' in REPO_URL:
        raise ValueError('Hãy thay REPO_URL bằng URL HTTPS của fork GitHub của bạn.')
    if (LAB_ROOT / 'data.yaml').is_file():
        print(f'Đã có repo tại {LAB_ROOT}; dùng bản hiện có.')
    elif LAB_ROOT.exists():
        raise RuntimeError(f'{LAB_ROOT} đã tồn tại nhưng không phải repo Day 4 hợp lệ. Đổi tên hoặc xoá thủ công rồi chạy lại.')
    else:
        subprocess.run(['git', 'clone', '--depth', '1', REPO_URL, str(LAB_ROOT)], check=True)
        print(f'Đã clone fork vào {LAB_ROOT}')
else:
    print('Bỏ qua clone. Hãy upload hoặc mount thư mục Day4-Lab trước khi chạy cell kế tiếp.')
# Out:
# Đã clone fork vào /content/Day4-Lab

# %%
# %pip -q install -U ultralytics

import json
import sys
from pathlib import Path

import torch
import yaml
from ultralytics import YOLO

# Cell 0 đã đặt LAB_ROOT khi bạn clone fork. Với upload/mount, đặt đúng đường dẫn ở đây.
LAB_ROOT = globals().get('LAB_ROOT', Path('/content/Day4-Lab'))
if not (LAB_ROOT / 'data.yaml').is_file():
    LAB_ROOT = Path.cwd() if (Path.cwd() / 'data.yaml').exists() else Path.cwd().parent
assert (LAB_ROOT / 'data.yaml').exists(), f'Không thấy data.yaml trong {LAB_ROOT}'

TRAIN_IMAGES = LAB_ROOT / 'dataset/images/train'
TRAIN_LABELS = LAB_ROOT / 'dataset/labels/train'
TEST_IMAGES = LAB_ROOT / 'dataset/images/test'
TEST_LABELS = LAB_ROOT / 'dataset/labels/test'
OUTPUTS = LAB_ROOT / 'outputs'
RUNS = OUTPUTS / 'runs'
OUTPUTS.mkdir(parents=True, exist_ok=True)
sys.path.insert(0, str(LAB_ROOT / 'tools'))

# Sinh data_colab.yaml trỏ 'path' vào đúng nơi vừa upload. File data.yaml gốc
# trong repo giữ nguyên, nên bạn commit lại mà không bị lệch đường dẫn.
config = yaml.safe_load((LAB_ROOT / 'data.yaml').read_text())
config['path'] = str(LAB_ROOT)
DATA_YAML = LAB_ROOT / 'data_colab.yaml'
DATA_YAML.write_text(yaml.safe_dump(config, sort_keys=False, allow_unicode=True))

DEVICE = 0 if torch.cuda.is_available() else 'cpu'
MODEL_NAME = 'yolo26n-pose.pt'   # đổi sang 'yolo11n-pose.pt' nếu muốn so hai thế hệ
print('LAB_ROOT :', LAB_ROOT)
print('device   :', DEVICE, '|', torch.cuda.get_device_name(0) if DEVICE == 0 else 'CPU - sẽ chậm')
print('kpt_shape:', config['kpt_shape'], '| flip_idx:', config['flip_idx'])
assert config['kpt_shape'] == [17, 3], 'kpt_shape phải là [17, 3], nếu không cờ visibility đã bị vứt'
# Out:
# LAB_ROOT : /content/Day4-Lab
# device   : cpu | CPU - sẽ chậm
# kpt_shape: [17, 3] | flip_idx: [0, 2, 1, 4, 3, 6, 5, 8, 7, 10, 9, 12, 11, 14, 13, 16, 15]

# %% [markdown]
# ## 1. Kiểm nhãn trước khi train
#
# Chạy đúng script bạn đã chạy ở local: 56 số một dòng, cờ chỉ nhận 0/1/2, đủ file cho từng ảnh.
# Một file nhãn hỏng ở đây sẽ thành một model hỏng ở dưới, mà không có dòng cảnh báo nào.

# %%
import subprocess

result = subprocess.run(
    [sys.executable, str(LAB_ROOT / 'tools/check_pose_labels.py'),
     '--images', str(TRAIN_IMAGES), '--labels', str(TRAIN_LABELS)],
    capture_output=True, text=True)
print(result.stdout or result.stderr)
assert result.returncode == 0, 'Nhãn train chưa đạt định dạng - sửa trước khi train'

from poselib import parse_yolo_pose_file

def count(label_dir):
    files = sorted(label_dir.glob('*.txt'))
    people = [p for f in files for p in parse_yolo_pose_file(f)]
    flags = [v for p in people for _, _, v in p.keypoints]
    return len(files), len(people), flags.count(2), flags.count(1), flags.count(0)

for name, directory in (('train (nhãn của bạn)', TRAIN_LABELS), ('test  (nhãn phát sẵn)', TEST_LABELS)):
    files, people, v2, v1, v0 = count(directory)
    print(f'{name}: {files} file, {people} skeleton, v=2 {v2}, v=1 {v1}, v=0 {v0}')
# Out:
# Đã đọc 20/20 file nhãn, 29 skeleton.
# Cờ visibility: v=2 335 | v=1 57 | v=0 101
#
# CẢNH BÁO (8) - không chặn nộp, nhưng phải xem lại:
# - train_02.txt:1: có 4 khớp v=0 trong khi cả người nằm gọn giữa ảnh. Khớp không ra khỏi khung được thì phải là v=1 (bị che, vẫn đặt chấm), không phải v=0
# - train_06.txt:1: có 7 khớp v=0 trong khi cả người nằm gọn giữa ảnh. Khớp không ra khỏi khung được thì phải là v=1 (bị che, vẫn đặt chấm), không phải v=0
# - train_09.txt:1: có 7 khớp v=0 trong khi cả người nằm gọn giữa ảnh. Khớp không ra khỏi khung được thì phải là v=1 (bị che, vẫn đặt chấm), không phải v=0
# - train_10.txt:1: có 5 khớp v=0 trong khi cả người nằm gọn giữa ảnh. Khớp không ra khỏi khung được thì phải là v=1 (bị che, vẫn đặt chấm), không phải v=0
# - train_11.txt:1: có 6 khớp v=0 trong khi cả người nằm gọn giữa ảnh. Khớp không ra khỏi khung được thì phải là v=1 (bị che, vẫn đặt chấm), không phải v=0
# - train_13.txt:1: có 6 khớp v=0 trong khi cả người nằm gọn giữa ảnh. Khớp không ra khỏi khung được thì phải là v=1 (bị che, vẫn đặt chấm), không phải v=0
# - train_14.txt:1: có 5 khớp v=0 trong khi cả người nằm gọn giữa ảnh. Khớp không ra khỏi khung được thì phải là v=1 (bị che, vẫn đặt chấm), không phải v=0
# - train_20.txt:1: có 4 khớp v=0 trong khi cả người nằm gọn giữa ảnh. Khớp không ra khỏi khung được thì phải là v=1 (bị che, vẫn đặt chấm), không phải v=0
#
# ĐẠT định dạng. Chạy tiếp tools/visibility_report.py, rồi chờ gold để chấm chất lượng.
#
# train (nhãn của bạn): 20 file, 29 skeleton, v=2 335, v=1 57, v=0 101
# test  (nhãn phát sẵn): 10 file, 13 skeleton, v=2 146, v=1 29, v=0 46

# %% [markdown]
# ## 2. Model gốc, chưa học gì từ nhãn của bạn
#
# `yolo26n-pose.pt` đã được train sẵn trên COCO - tức là nó **đã biết** bộ 17 điểm này.
# Đo nó trên tập test trước, để lát nữa có mốc mà so. Đây là baseline, không phải đối thủ.

# %%
baseline_model = YOLO(MODEL_NAME)
baseline_metrics = baseline_model.val(
    data=str(DATA_YAML), split='val', device=DEVICE, plots=False,
    project=str(RUNS), name='baseline', exist_ok=True)

def summarize(metrics):
    return {
        'pose_mAP50': round(float(metrics.pose.map50), 4),
        'pose_mAP50_95': round(float(metrics.pose.map), 4),
        'pose_precision': round(float(metrics.pose.mp), 4),
        'pose_recall': round(float(metrics.pose.mr), 4),
        'box_mAP50': round(float(metrics.box.map50), 4),
        'box_mAP50_95': round(float(metrics.box.map), 4),
    }

baseline = summarize(baseline_metrics)
print(json.dumps(baseline, indent=2))
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n-pose.pt to 'yolo26n-pose.pt': 100% ━━━━━━━━━━━━ 7.5MB 28.3MB/s 0.3s
# Ultralytics 8.4.153 🚀 Python-3.13.15 torch-2.11.0+cpu CPU (AMD EPYC 7B12)
# YOLO26n-pose summary (fused): 129 layers, 2,926,494 parameters, 0 gradients, 7.6 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 5.1MB/s 0.1s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1480.9±633.3 MB/s, size: 69.3 KB)
# val: Scanning /content/Day4-Lab/dataset/labels/test... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 210.0it/s 0.0s
# val: New cache created: /content/Day4-Lab/dataset/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.8s/it 1.8s
#                    all         10         13      0.995      0.923      0.979      0.812      0.973      0.846      0.845      0.685
# Speed: 3.6ms preprocess, 162.6ms inference, 0.0ms loss, 3.5ms postprocess per image
# {
#   "pose_mAP50": 0.845,
#   "pose_mAP50_95": 0.6853,
#   "pose_precision": 0.9734,
#   "pose_recall": 0.8462,
#   "box_mAP50": 0.9785,
#   "box_mAP50_95": 0.8119
# }

# %% [markdown]
# ## 3. Fine-tune trên nhãn của bạn
#
# `fliplr=0.5` là augmentation lật ảnh ngang. Ultralytics đọc `flip_idx` trong `data.yaml`
# để đổi tên khớp trái/phải cho ảnh lật. Đây chính là slide 15: nếu nhãn của bạn đảo trái/phải,
# model được dạy cái sai đó **hai lần** - một lần ở ảnh gốc, một lần ở ảnh lật.
#
# Muốn thấy tận mắt: chạy lại cell này với `fliplr=0.0` và so `pose_mAP50-95`.

# %%
model = YOLO(MODEL_NAME)
train_result = model.train(
    data=str(DATA_YAML),
    epochs=80,
    imgsz=640,
    batch=8,
    device=DEVICE,
    workers=2,
    project=str(RUNS),
    name='pose_finetune',
    exist_ok=True,
    seed=20260915,
    fliplr=0.5,
    plots=True,
    patience=30,
)
BEST = Path(model.trainer.best)
print('checkpoint tốt nhất:', BEST)
# Out:
# Ultralytics 8.4.153 🚀 Python-3.13.15 torch-2.11.0+cpu CPU (AMD EPYC 7B12)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Day4-Lab/data_colab.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=pose_finetune, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/Day4-Lab/outputs/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/Day4-Lab/outputs/runs/pose_finetune, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=20260915, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   1416840  ultralytics.nn.modules.head.Pose26           [1, [17, 3], 1, True, [64, 128, 256]]
# YOLO26n-pose summary: 363 layers, 3,679,464 parameters, 3,679,464 gradients, 10.4 GFLOPs
#
# Transferred 879/879 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2727.7±1316.9 MB/s, size: 83.8 KB)
# train: Scanning /content/Day4-Lab/dataset/labels/train.cache... 20 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20/20 6.0Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2808.9±1090.8 MB/s, size: 75.8 KB)
# val: Scanning /content/Day4-Lab/dataset/labels/test.cache... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 3.0Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 126 weight(decay=0.0), 186 weight(decay=0.0005), 186 bias(decay=0.0)
# Plotting labels to /content/Day4-Lab/outputs/runs/pose_finetune/labels.jpg...
# Using 20 train, 10 val images for fraction=1.0 at imgsz=640
# Using 0 dataloader workers
# Logging results to /content/Day4-Lab/outputs/runs/pose_finetune
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        1/80         0G     0.8485      1.606     0.2401     0.4919    0.01094       1.18         14        640: 100% ━━━━━━━━━━━━ 3/3 5.2s/it 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.7s/it 2.7s
#                    all         10         13      0.995      0.923      0.979      0.804      0.975      0.846      0.845      0.685
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        2/80         0G       1.44      3.192     0.2021     0.8739    0.01949      6.325         18        640: 100% ━━━━━━━━━━━━ 3/3 6.4s/it 19.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.4s/it 2.4s
#                    all         10         13      0.995      0.923      0.986      0.503      0.888      0.769       0.73      0.193
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        3/80         0G      1.754      4.134     0.2632     0.8108    0.02679      8.395         14        640: 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.995      0.923      0.986      0.503      0.888      0.769       0.73      0.193
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        4/80         0G      1.581      3.749     0.2852      0.785    0.02513      7.603         12        640: 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.964      0.846      0.926      0.392      0.465      0.154      0.133     0.0351
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        5/80         0G      1.845      5.155      0.342     0.9731    0.02563      7.581         18        640: 100% ━━━━━━━━━━━━ 3/3 5.3s/it 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.964      0.846      0.926      0.392      0.465      0.154      0.133     0.0351
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        6/80         0G      1.744      5.319     0.3394     0.8806    0.02778      9.762         13        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 14.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8s/it 2.8s
#                    all         10         13      0.911      0.769      0.886        0.5      0.389      0.308      0.275     0.0675
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        7/80         0G      1.773      4.813     0.4143      1.118    0.02757      7.217         15        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.4s/it 2.4s
#                    all         10         13      0.911      0.769      0.886        0.5      0.389      0.308      0.275     0.0675
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        8/80         0G      1.845      4.377     0.4504     0.9355    0.02592      6.848         15        640: 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.911      0.769      0.886        0.5      0.389      0.308      0.275     0.0675
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        9/80         0G      1.519      3.785      0.431     0.9341    0.02688      6.339         13        640: 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.4s/it 2.4s
#                    all         10         13      0.606      0.846       0.78       0.41      0.664      0.304      0.327      0.093
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       10/80         0G      1.459      4.136      0.399     0.9647    0.02371      7.023         15        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 14.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.606      0.846       0.78       0.41      0.664      0.304      0.327      0.093
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       11/80         0G      1.408      3.289      0.392     0.8163    0.02209      4.944         12        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8s/it 2.8s
#                    all         10         13      0.409      0.923      0.613      0.322      0.574      0.538       0.46      0.136
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       12/80         0G      1.584      4.031     0.3646      0.977    0.02635      7.361         11        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.409      0.923      0.613      0.322      0.574      0.538       0.46      0.136
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       13/80         0G      1.659      3.873     0.3888     0.9364    0.02847      6.353         13        640: 100% ━━━━━━━━━━━━ 3/3 5.2s/it 15.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.533      0.614       0.62      0.286      0.515      0.615      0.494      0.168
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       14/80         0G      1.629       3.25     0.3466     0.9327    0.02457       5.27         16        640: 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6s/it 2.6s
#                    all         10         13      0.533      0.614       0.62      0.286      0.515      0.615      0.494      0.168
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       15/80         0G      1.575      3.546     0.3592      1.063    0.02316      5.639         16        640: 100% ━━━━━━━━━━━━ 3/3 5.2s/it 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6s/it 2.6s
#                    all         10         13      0.533      0.614       0.62      0.286      0.515      0.615      0.494      0.168
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       16/80         0G      1.356      3.064     0.3422     0.7221    0.01995      4.478         21        640: 100% ━━━━━━━━━━━━ 3/3 5.2s/it 15.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8s/it 2.8s
#                    all         10         13      0.591          1      0.849      0.435      0.677      0.485      0.616      0.191
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       17/80         0G      1.335      3.214     0.3273     0.6967    0.02122      4.537         19        640: 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.591          1      0.849      0.435      0.677      0.485      0.616      0.191
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       18/80         0G      1.342      3.595     0.3392     0.8212    0.02095      4.581         16        640: 100% ━━━━━━━━━━━━ 3/3 5.2s/it 15.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6s/it 2.6s
#                    all         10         13      0.812          1      0.976      0.536      0.613      0.769      0.624      0.238
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       19/80         0G      1.543      3.216     0.3374     0.8919    0.02545      4.949         12        640: 100% ━━━━━━━━━━━━ 3/3 5.7s/it 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8s/it 2.8s
#                    all         10         13      0.812          1      0.976      0.536      0.613      0.769      0.624      0.238
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       20/80         0G      1.525      3.687     0.3175     0.9122    0.02559      4.541         14        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13       0.94      0.923       0.99      0.551       0.78      0.769      0.761       0.23
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       21/80         0G      1.334      2.838     0.3471     0.5976    0.02261      4.607         14        640: 100% ━━━━━━━━━━━━ 3/3 5.3s/it 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6s/it 2.6s
#                    all         10         13       0.94      0.923       0.99      0.551       0.78      0.769      0.761       0.23
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       22/80         0G       1.28      2.999     0.3212     0.6771    0.01896      4.502         19        640: 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.4s/it 2.4s
#                    all         10         13       0.94      0.923       0.99      0.551       0.78      0.769      0.761       0.23
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       23/80         0G      1.329      3.224      0.327     0.9735    0.02177      4.853         16        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 14.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.958      0.923       0.99      0.567      0.684      0.769      0.645      0.227
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       24/80         0G      1.184      3.034     0.3147     0.7112    0.01777      4.861         10        640: 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.7s/it 2.7s
#                    all         10         13      0.958      0.923       0.99      0.567      0.684      0.769      0.645      0.227
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       25/80         0G      1.379      3.013     0.2856     0.7621    0.02256      5.512         15        640: 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.928      0.998       0.99      0.587      0.784      0.846      0.765      0.254
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       26/80         0G      1.224      2.287     0.3303     0.6024     0.0215      3.978         11        640: 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6s/it 2.6s
#                    all         10         13      0.928      0.998       0.99      0.587      0.784      0.846      0.765      0.254
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       27/80         0G      1.206      2.732     0.2925     0.7034    0.01991      3.853         12        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6s/it 2.6s
#                    all         10         13      0.906          1      0.962      0.546      0.802      0.692       0.68       0.27
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       28/80         0G      1.363      2.857     0.3155     0.6213    0.02009      3.778         18        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.906          1      0.962      0.546      0.802      0.692       0.68       0.27
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       29/80         0G       1.27       2.26     0.3386      0.599    0.02232      3.861         12        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8s/it 2.8s
#                    all         10         13      0.906          1      0.962      0.546      0.802      0.692       0.68       0.27
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       30/80         0G      1.247       2.42     0.3015     0.5986    0.01627      3.354         16        640: 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6s/it 2.6s
#                    all         10         13      0.847          1      0.944      0.479      0.757      0.769      0.678       0.27
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       31/80         0G      1.186      2.033      0.341     0.6513    0.01833      3.532         13        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5s/it 2.5s
#                    all         10         13      0.847          1      0.944      0.479      0.757      0.769      0.678       0.27
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 31 epochs completed in 0.159 hours.
# Optimizer stripped from /content/Day4-Lab/outputs/runs/pose_finetune/weights/last.pt, 7.8MB
# Optimizer stripped from /content/Day4-Lab/outputs/runs/pose_finetune/weights/best.pt, 7.8MB
#
# Validating /content/Day4-Lab/outputs/runs/pose_finetune/weights/best.pt...
# Ultralytics 8.4.153 🚀 Python-3.13.15 torch-2.11.0+cpu CPU (AMD EPYC 7B12)
# YOLO26n-pose summary (fused): 129 layers, 2,926,494 parameters, 0 gradients, 7.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5s/it 1.5s
#                    all         10         13      0.995      0.923      0.979      0.804      0.975      0.846      0.845      0.685
# Speed: 1.5ms preprocess, 147.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /content/Day4-Lab/outputs/runs/pose_finetune
# checkpoint tốt nhất: /content/Day4-Lab/outputs/runs/pose_finetune/weights/best.pt

# %% [markdown]
# ## 4. Đánh giá trên đúng tập test
#
# `data.yaml` trỏ `val` tới 10 ảnh test đã có nhãn phát sẵn. Không đổi nó sang train.
#
# `pose_mAP` chấm bằng **OKS** - đúng thước đo bạn đã dùng để chấm nhãn của mình ở
# `tools/evaluate_pose_annotations.py`. Cùng một công thức, một bên đo người, một bên đo model.

# %%
best_model = YOLO(str(BEST))
finetuned_metrics = best_model.val(
    data=str(DATA_YAML), split='val', device=DEVICE, plots=True,
    project=str(RUNS), name='pose_eval', exist_ok=True)
finetuned = summarize(finetuned_metrics)

comparison = {'baseline_' + MODEL_NAME.replace('.pt', ''): baseline, 'finetuned': finetuned,
              'delta': {k: round(finetuned[k] - baseline[k], 4) for k in baseline}}
(OUTPUTS / 'eval_model.json').write_text(json.dumps(comparison, ensure_ascii=False, indent=2))

header = f"{'chỉ số':<16}{'gốc':>10}{'sau fine-tune':>16}{'chênh':>10}"
print(header); print('-' * len(header))
for key in baseline:
    print(f'{key:<16}{baseline[key]:>10.4f}{finetuned[key]:>16.4f}{comparison["delta"][key]:>+10.4f}')
print('\nĐã ghi outputs/eval_model.json')
# Out:
# Ultralytics 8.4.153 🚀 Python-3.13.15 torch-2.11.0+cpu CPU (AMD EPYC 7B12)
# YOLO26n-pose summary (fused): 129 layers, 2,926,494 parameters, 0 gradients, 7.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2048.4±786.7 MB/s, size: 86.8 KB)
# val: Scanning /content/Day4-Lab/dataset/labels/test.cache... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 2.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all         10         13      0.995      0.923      0.979      0.804      0.975      0.846      0.845      0.685
# Speed: 2.2ms preprocess, 153.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /content/Day4-Lab/outputs/runs/pose_eval
# chỉ số                 gốc   sau fine-tune     chênh
# ----------------------------------------------------
# pose_mAP50          0.8450          0.8450   +0.0000
# pose_mAP50_95       0.6853          0.6853   +0.0000
# pose_precision      0.9734          0.9749   +0.0015
# pose_recall         0.8462          0.8462   +0.0000
# box_mAP50           0.9785          0.9785   +0.0000
# box_mAP50_95        0.8119          0.8044   -0.0075
#
# Đã ghi outputs/eval_model.json

# %% [markdown]
# ## 5. Nhìn tận mắt - 10 ảnh test kèm pose model đoán
#
# Con số ở trên không nói cho bạn biết model sai **kiểu gì**. Bốn kiểu sai của slide 43
# (lệch nhẹ / đảo trái/phải / nhầm người / trượt hẳn) áp cho model y như áp cho người.

# %%
import math

import matplotlib.pyplot as plt
from PIL import Image

PRED_DIR = RUNS / 'predictions'
best_model.predict(source=str(TEST_IMAGES), conf=0.25, device=DEVICE, save=True,
                   project=str(PRED_DIR), name='test', exist_ok=True)
predicted = sorted((PRED_DIR / 'test').glob('*.jpg'))

columns = 5
rows = math.ceil(len(predicted) / columns)
figure, axes = plt.subplots(rows, columns, figsize=(4 * columns, 3.2 * rows))
for axis, path in zip(axes.flat, predicted):
    axis.imshow(Image.open(path)); axis.set_title(path.stem, fontsize=9)
for axis in axes.flat:
    axis.axis('off')
plt.tight_layout(); plt.show()
# Out:
# image 1/10 /content/Day4-Lab/dataset/images/test/test_01.jpg: 640x576 1 person, 169.2ms
# image 2/10 /content/Day4-Lab/dataset/images/test/test_02.jpg: 448x640 1 person, 119.8ms
# image 3/10 /content/Day4-Lab/dataset/images/test/test_03.jpg: 448x640 2 persons, 99.2ms
# image 4/10 /content/Day4-Lab/dataset/images/test/test_04.jpg: 480x640 1 person, 122.7ms
# image 5/10 /content/Day4-Lab/dataset/images/test/test_05.jpg: 640x448 1 person, 144.8ms
# image 6/10 /content/Day4-Lab/dataset/images/test/test_06.jpg: 576x640 2 persons, 187.7ms
# image 7/10 /content/Day4-Lab/dataset/images/test/test_07.jpg: 608x640 1 person, 197.4ms
# image 8/10 /content/Day4-Lab/dataset/images/test/test_08.jpg: 352x640 1 person, 118.3ms
# image 9/10 /content/Day4-Lab/dataset/images/test/test_09.jpg: 480x640 2 persons, 141.0ms
# image 10/10 /content/Day4-Lab/dataset/images/test/test_10.jpg: 512x640 1 person, 157.1ms
# Speed: 4.1ms preprocess, 145.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /content/Day4-Lab/outputs/runs/predictions/test

# %% [markdown]
# ## 6. Nhãn của bạn vs model chấm thử, trên chính tập train
#
# Slide 27: model chấm thử **một lần để đối chiếu, không phải đáp án**. Bạn đã tự gán xong
# và đã qua cổng gold rồi, nên bây giờ mới được nhìn.
#
# Chỗ nào model và bạn lệch nhau nhiều: hoặc model sai (ảnh khó), hoặc nhãn của bạn sai
# (và gold đã chỉ ra rồi). Ghi lại 2-3 ca vào báo cáo.

# %%
from poselib import Person, greedy_match, image_size

OUT_OF_FRAME = 0
rows_out = []
for image_path in sorted(TRAIN_IMAGES.glob('*.jpg')):
    width, height = image_size(image_path)
    mine = parse_yolo_pose_file(TRAIN_LABELS / f'{image_path.stem}.txt')
    prediction = best_model.predict(source=str(image_path), conf=0.25, device=DEVICE, verbose=False)[0]
    theirs = []
    for box, keypoints in zip(prediction.boxes.xywhn.tolist(), prediction.keypoints.data.tolist()):
        points = [(x / width, y / height, 2 if score >= 0.5 else 1) if score > 0.05 else (0.0, 0.0, OUT_OF_FRAME)
                  for x, y, score in keypoints]
        theirs.append(Person(tuple(box), points))
    matched, extra, missed = greedy_match(theirs, mine, width, height)
    for _, _, score in matched:
        rows_out.append((image_path.stem, round(score, 3)))
    if extra or missed:
        rows_out.append((image_path.stem + ' (số người lệch)', f'model {len(theirs)} / bạn {len(mine)}'))

print(f"{'ảnh':<28}{'OKS model vs nhãn của bạn':>28}")
for stem, value in sorted(rows_out, key=lambda r: (isinstance(r[1], str), r[1])):
    print(f'{stem:<28}{value:>28}')
print('\nOKS thấp = model và bạn bất đồng. Xem lại ảnh đó bằng tools/visualize_pose.py.')
# Out:
# ảnh                            OKS model vs nhãn của bạn
# train_01                                           0.017
# train_15                                           0.662
# train_14                                           0.728
# train_03                                            0.75
# train_13                                           0.862
# train_16                                            0.87
# train_16                                           0.879
# train_12                                           0.884
# train_10                                           0.901
# train_03                                           0.933
# train_19                                           0.934
# train_18                                           0.938
# train_13                                           0.941
# train_11                                           0.949
# train_02                                           0.953
# train_05                                           0.953
# train_15                                           0.955
# train_06                                           0.957
# train_04                                           0.964
# train_01                                           0.966
# train_17                                           0.967
# train_09                                            0.97
# train_08                                           0.974
# train_20                                           0.975
# train_07                                           0.977
# train_04                                           0.978
# train_19                                            0.98
# train_13                                           0.984
# train_14                                           0.985
# train_09 (số người lệch)                 model 2 / bạn 1
# train_10 (số người lệch)                 model 2 / bạn 1
# train_12 (số người lệch)                 model 2 / bạn 1
# train_03 (số người lệch)                 model 3 / bạn 2
#
# OKS thấp = model và bạn bất đồng. Xem lại ảnh đó bằng tools/visualize_pose.py.

# %% [markdown]
# ## Câu hỏi phân tích để nộp
#
# Trả lời trong `reports/REPORT.md`:
#
# 1. `pose_mAP50-95` thay đổi bao nhiêu sau fine-tune? Nếu nó **giảm**, hãy giải thích:
#    20 ảnh của bạn dạy được model điều gì mà COCO chưa dạy, và nó làm hỏng điều gì?
# 2. `box_mAP` và `pose_mAP` chênh nhau bao nhiêu? Model tìm *người* dễ hơn hay tìm *khớp* dễ hơn?
# 3. Ở mục 5, tìm một ảnh model đoán sai. Gọi tên lỗi theo bốn loại của slide 43.
# 4. Ở mục 6, ảnh nào có OKS thấp nhất giữa bạn và model? Ai đúng - và bạn dựa vào đâu để nói vậy?
# 5. Trong `tools/evaluate_pose_annotations.py` bạn đã có OKS nhãn-của-bạn vs gold.
#    Ảnh nào bạn gán tệ nhất *cũng* là ảnh model đoán tệ nhất? Nếu có, điều đó nói gì về ảnh đó?
